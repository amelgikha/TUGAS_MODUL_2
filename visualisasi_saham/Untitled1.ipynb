# %%
import numpy as np
import pandas as pd

df = pd.read_csv(
    'AAPL.csv',
    index_col = False,
    parse_dates = ['Date']
)
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2015-12-31  107.010002  107.029999  104.820000  105.260002   98.657883
# 1   2016-01-04  102.610001  105.370003  102.000000  105.349998   98.742249
# 2   2016-01-05  105.750000  105.849998  102.410004  102.709999   96.267815
# 3   2016-01-06  100.559998  102.370003   99.870003  100.699997   94.383888
# 4   2016-01-07   98.680000  100.129997   96.430000   96.449997   90.400467
# ..         ...         ...         ...         ...         ...         ...
# 896 2019-07-25  208.889999  209.240005  206.729996  207.020004  206.236420
# 897 2019-07-26  207.479996  209.729996  207.139999  207.740005  206.953690
# 898 2019-07-29  208.460007  210.639999  208.440002  209.679993  208.886337
# 899 2019-07-30  208.759995  210.160004  207.309998  208.779999  207.989746
# 900 2019-07-31  216.419998  221.369995  211.300003  213.039993  212.233627
#
#        Volume
# 0    40912300
# 1    67649400
# 2    55791000
# ...

# %%
df.columns = ['Est','Tes']
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-626078a75ffc> in <module>
# ----> 1 df.columns = ['Est','Tes']
#       2 df
#
# NameError: name 'df' is not defined

# %%
df['selisih']= df.apply(lambda baris : baris['Est'] - baris['Close'], axis =1)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-60f06d150d46> in <module>
# ----> 1 df['selisih']= df.apply(lambda baris : baris['Est'] - baris['Close'], axis =1)
#       2 df
#
# NameError: name 'df' is not defined

# %%
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2015-12-31  107.010002  107.029999  104.820000  105.260002   98.657883
# 1   2016-01-04  102.610001  105.370003  102.000000  105.349998   98.742249
# 2   2016-01-05  105.750000  105.849998  102.410004  102.709999   96.267815
# 3   2016-01-06  100.559998  102.370003   99.870003  100.699997   94.383888
# 4   2016-01-07   98.680000  100.129997   96.430000   96.449997   90.400467
# ..         ...         ...         ...         ...         ...         ...
# 896 2019-07-25  208.889999  209.240005  206.729996  207.020004  206.236420
# 897 2019-07-26  207.479996  209.729996  207.139999  207.740005  206.953690
# 898 2019-07-29  208.460007  210.639999  208.440002  209.679993  208.886337
# 899 2019-07-30  208.759995  210.160004  207.309998  208.779999  207.989746
# 900 2019-07-31  216.419998  221.369995  211.300003  213.039993  212.233627
#
#        Volume   selisih
# 0    40912300  1.750000
# ...
